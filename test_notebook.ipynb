# %% [markdown]
# ## Test jupyter notebook

# %%
from ma_pytemp.gui.default_colors import DefaultColors


DefaultColors.dark_grey.value
# Out:
# '#404040'

# %%
l = [1,2,3]
", ".join([str(i) for i in l])
# Out:
# '1, 2, 3'
